# %% [markdown]
# # **INSTALL AND IMPORT**
#
# ---
# When working in colab installing of matplotlib instance in not required,but to import the library we have to do.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Plotting first simple graph
#
# ---
#
# In a Jupyter notebook, we can simply output the graphs within the notebook itself by running the %matplotlib inline magic command.

# %%
**Line Graph**

# %% [markdown]
# Now lets plot our first graph

# %%
plt.plot([1,2,3,4,5],[5,4,3,4,5])
plt.show()

# %% [markdown]
# Now lets try for some trigonometric function

# %%
x=np.linspace(-2,2,500)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %% [markdown]
# If we want to add some style to line plot ,we can use for example g--,"g--" means "green dashed line".

# %%
x=np.linspace(-3,3,500)
plt.plot(x,x**2,'g--')
plt.show()

# %%
x=np.linspace(-2,2,30)
plt.plot(x,x,'r--',x,x**2,'g^',x,x**3,'b:')
plt.show()

# %% [markdown]
# # **SUBPLOT**
#
# ---
# To create a subplot, just call the subplot function, and specify the number of rows and columns in the figure, and the index of the subplot you want to draw on (starting from 1, then left to right, and top to bottom). Note that pyplot keeps track of the currently active subplot (which you can get a reference to by calling plt.gca()), so when you call the plot function, it draws on the active subplot.

# %%
x=np.linspace(-1,1,40)
plt.subplot(4,4,1)
plt.plot(x,x)
plt.subplot(4,4,2)
plt.plot(x,x**2)
plt.subplot(4,4,3)
plt.plot(x,x**3)
plt.subplot(4,4,4)
plt.plot(x,x)
plt.show()

# %%
def f(x):
  return np.exp(-x)*np.cos(2*np.pi*x)

x1 = np.arange(0.0, 5.0, 0.1)
x2 = np.arange(0.0, 5.0, 0.02)
plt.subplot(211)
plt.plot(x1,f(x1),color='tab:blue',marker='o')
plt.plot(x2,f(x2),color='black')
plt.subplot(212)
plt.plot(x1,np.cos(2*np.pi*x1),color='tab:orange',linestyle='--')
plt.show()

# %% [markdown]
# # **Adding Text to graph**
#
# ---
# You can call text to add text at any location in the graph. Just specify the horizontal and vertical coordinates and the text, and optionally some extra attributes.

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.set_title('Axes title ',color='red')
ax.set_xlabel('X label',color='yellow')
ax.set_ylabel('Y label',color='yellow')
y=np.linspace(-1,1,50)
x=y**2
ax.plot(y,x,color='tab:blue',linestyle='solid')
ax.text(0,0.6,"Quadratic equation of the form \n$y = x^2$",fontweight='bold',fontsize=10, color='blue', horizontalalignment="center")
# Out:
# Text(0, 0.6, 'Quadratic equation of the form \n$y = x^2$')

# %% [markdown]
# # **Legend**

# %%
y=np.linspace(-1,1,30)
x=y**3
plt.plot(y,x,color='tab:red',label='Cube function')
plt.plot(x,x**2,color='tab:green',label='Square Function')
plt.legend(loc="best",fancybox=True)
